# %%
import pandas as pd
pd.__version__
# Out:
# Running cells with 'Python 3.11.9' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/home/henryque/.local/bin/python3.11 -m pip install ipykernel -U --user --force-reinstall'

# %%
dict_medidas = {'idade': [15,18,25,25,40,55,58,60,80], 'altura': [160,162,165,168,172,174,174, 174,176]}
dict_medidas

# %%
df_medidas = pd.DataFrame.from_dict(dict_medidas)
df_medidas

# %% [markdown]
# ### Medidas de posição

# %%
# Media
df_medidas["idade"].mean()

# %%
#mediana
df_medidas['idade'].median()

# %%
df_medidas['idade'].mode()

# %% [markdown]
# ### Medidas de dispersão

# %%
# variancia
df_medidas.idade.var()

# %%
# desvio padrão
df_medidas.idade.std()

# %%
# coeficiente de variação
df_medidas.idade.std() / df_medidas.idade.mean() * 100

df_medidas.altura.std()/df_medidas.altura.mean()*100

(df_medidas.idade.std() / df_medidas.idade.mean() * 100, df_medidas.altura.std()/df_medidas.altura.mean()*100)

# %% [markdown]
# ### medidas de forma

# %%
# Assimetria idade
df_medidas.idade.skew()

# %%
# Assimetria altura
df_medidas.altura.skew()

# %%
# Curtose - Idade
df_medidas.idade.kurtosis()

# %%
# Curtose - altura
df_medidas.altura.kurtosis()

# %%
df_medidas.idade.describe()

# %% [markdown]
# ### Correlação de variáveis

# %%
# Correlação do DataFrame
df_medidas.corr(method='pearson')

# %%
# Correlação entre 2 variáveis
# O metodo de pearson mede correlação linear entre duas variáveis.
df_medidas.idade.corr(df_medidas.altura)

# %%
# Correlação do DataFrame,segundo Spearman
df_medidas.corr(method='spearman')

# %% [markdown]
# ### representações gráficas

# %%
df_medidas.idade.hist()

# %%
df_medidas.altura.hist()

# %% [markdown]
# ### DataFrame de vendas

# %%
dict_vendas = {'categoria': ['masculino','feminino', 'infantil', 'casa'], 'valor': [400000, 600000, 250000, 580000], 'quantidade': [3000, 5000, 1500, 2500]}
dict_vendas

# %%
df_vendas = pd.DataFrame.from_dict(dict_vendas)
df_vendas

# %%
# Gráfico de barras vertical - valor
df_vendas.plot.bar(x='categoria',y='valor')

# %%
# Gráfico de barras vertical - valor ordenado
df_vendas.sort_values('valor', ascending=False).plot.bar(x='categoria',y='valor')

# %%
#Gráfico de barras horizontal - Quantidade
df_vendas.plot.barh(x='categoria',y='quantidade')

# %%
# Gráfico de Barras Horizontal - Quantidade Ordenado
df_vendas.sort_values('quantidade').plot.barh(x='categoria',y='quantidade')

# %%
# Gráfico de dispersão
df_medidas.plot.scatter(x='idade',y='altura')

# %%
# Gráfico de BoxSplot - Idade
df_medidas.idade.plot.box()

# %%
# Gráfico de BoxPlot - Altura
df_medidas.altura.plot.box()

# %%
# DataFrame com dados temporais
dict_faturamento = {'data_ref': ['2019-01-01', '2020-01-01', '2021-01-01', '2022-01-01', '2023-01-01'], 'valor': [400000, 800000, 500000, 800000, 900000]}
dict_faturamento

# %%
df_faturamento = pd.DataFrame.from_dict(dict_faturamento)
df_faturamento

# %%
df_faturamento.info()

# %%
df_faturamento['data_ref'] = pd.to_datetime(df_faturamento['data_ref'])
df_faturamento.info()

# %%
# Gráfico de linhas
df_faturamento.plot.line(x='data_ref',y='valor')
